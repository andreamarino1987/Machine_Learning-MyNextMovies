# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')

movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings = pd.read_csv('ratings.csv')
ratings = ratings.drop('timestamp', axis=1)
ratings
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %%
links = pd.read_csv('links.csv')

links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
tags = pd.read_csv('tags.csv')
tags = tags.drop('timestamp', axis=1)

tags
# Out:
#       userId  movieId               tag
# 0          2    60756             funny
# 1          2    60756   Highly quotable
# 2          2    60756      will ferrell
# 3          2    89774      Boxing story
# 4          2    89774               MMA
# ...      ...      ...               ...
# 3678     606     7382         for katie
# 3679     606     7936           austere
# 3680     610     3265            gun fu
# 3681     610     3265  heroic bloodshed
# 3682     610   168248  Heroic Bloodshed
#
# [3683 rows x 3 columns]

# %%
genome_tags =pd.read_csv('genome-tags.csv')
genome_tags
# Out:
#       tagId           tag
# 0         1           007
# 1         2  007 (series)
# 2         3  18th century
# 3         4         1920s
# 4         5         1930s
# ...     ...           ...
# 1123   1124       writing
# 1124   1125         wuxia
# 1125   1126          wwii
# 1126   1127        zombie
# 1127   1128       zombies
#
# [1128 rows x 2 columns]

# %%
genome_scores = pd.read_csv('genome-scores.csv')

genome_scores


#genome_scores.loc[genome_scores['movieId']==1][:10]

#genome_scores
# Out:
#           movieId  tagId  relevance
# 0               1      1    0.02900
# 1               1      2    0.02375
# 2               1      3    0.05425
# 3               1      4    0.06875
# 4               1      5    0.16000
# ...           ...    ...        ...
# 14862523   187595   1124    0.10700
# 14862524   187595   1125    0.05850
# 14862525   187595   1126    0.03800
# 14862526   187595   1127    0.10225
# 14862527   187595   1128    0.02925
#
# [14862528 rows x 3 columns]

# %%
cut = []

for i in range(187596):
    process = genome_scores.loc[genome_scores['movieId'] == i][:10]
    cut.append(process)
    
new_genome_scores = pd.concat(cut)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-f7f58adc1b7a> in <module>
#       2
#       3 for i in range(187596):
# ----> 4     process = genome_scores.loc[genome_scores['movieId'] == i][:10]
#       5     cut.append(process)
#       6
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
# ...

# %%
df = pd.merge(movies, ratings, on = 'movieId', how = 'inner')

df
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
#df.dtypes

# %%
df2 = pd.merge(df, tags, on = 'movieId', how = 'inner')
df2
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
df3 = pd.merge(df2, genome_scores, on = 'movieId', how = 'inner')
df3
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-bed056d8471e> in <module>
# ----> 1 df3 = pd.merge(df2, genome_scores, on = 'movieId', how = 'inner')
#       2 df3
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
# ...

# %%
df2
# Out:
#        movieId                                              title  \
# 0         4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 1         4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2         4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 3         4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 4         4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# ...        ...                                                ...
# 64641    33493  Star Wars: Episode III - Revenge of the Sith (...
# 64642    33493  Star Wars: Episode III - Revenge of the Sith (...
# 64643    33493  Star Wars: Episode III - Revenge of the Sith (...
# 64644    33493  Star Wars: Episode III - Revenge of the Sith (...
# 64645    33493  Star Wars: Episode III - Revenge of the Sith (...
#
#                         genres  userId_x  rating  userId_y  \
# 0               Comedy|Romance     20043     5.0       268
# ...

# %%
df2.loc[df2['movieId'] == 4973]
# Out:
#       movieId                                              title  \
# 0        4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 1        4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2        4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 3        4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 4        4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# ...       ...                                                ...
# 2268     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2269     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2270     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2271     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 2272     4973  Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
#
#               genres  userId_x  rating  userId_y                       tag
# 0     Comedy|Romance     20043     5.0       268                    ohsoso
# ...

# %%
df4 = pd.merge(df3, genome_tags, on = 'tagId', how = 'inner')
df4
